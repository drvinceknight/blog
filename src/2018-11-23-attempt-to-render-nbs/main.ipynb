# %% [markdown]
# title: Attempt to render a nb
# description: An attempt to render a notebook

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %% [markdown]
# Going to convert this to markdown and then to html perhaps...

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Trying to include a sub title

# %% [markdown]
# Some more complicated code now:

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([1, 2, 3], (4, 5, 1));

# %% [markdown]
# Let me check how the mathematics renders: \\(x + y = z\\) and some display mode:
#
# \\[
#  \int_0^{\infty} 1/x dx
# \\]

# %% [markdown]
# What about a code snippet:
#
#     for i in range(2):
#         print(i)
